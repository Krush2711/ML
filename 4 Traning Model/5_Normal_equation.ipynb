# %%
import numpy as np

# %% [markdown]
# y = mx + b

# %%
x = np.array([1, 2, 3])
y = np.array([1 , 3,  3])

# %% [markdown]
# Add column of the 1 in X ( bais )

# %%
X = np.c_[np.ones(len(x)), x]
X
# Out:
# array([[1., 1.],
#        [1., 2.],
#        [1., 3.]])

# %%
theta = np.linalg.inv(X.T @ X) @ X.T @ y
theta
# Out:
# array([0.33333333, 1.        ])

# %% [markdown]
# @ reffers to the matrix multiplication in the python

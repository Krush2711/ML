# %%
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
x, y = make_classification(
    n_samples=1000,
    n_features=20,
    n_informative=5,
    n_redundant=5,
    n_classes=2,
    flip_y=0.1,   # add noise
    random_state=42
)

# %%
x_t, x_tt, y_t, y_tt = train_test_split(x, y, test_size=.3, random_state=42)

# %%
lr =LogisticRegression()
dt = DecisionTreeClassifier()

# %%
for model in [lr, dt]:
    clf = model
    clf.fit(x_t, y_t)
    y_pred = clf.predict(x_tt)
    print(f"{model} accuracy :" , accuracy_score(y_tt, y_pred))
    print(confusion_matrix(y_tt, y_pred))
    print()
    print("----"*50)
# Out:
# LogisticRegression() accuracy : 0.7966666666666666
# [[108  31]
#  [ 30 131]]
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# DecisionTreeClassifier() accuracy : 0.7933333333333333
# [[105  34]
#  [ 28 133]]
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
bag_dt = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=100,
    max_samples=1.0,
    bootstrap=True,
    oob_score=True,
    random_state=42,
    n_jobs=-1
)
bag_dt.fit(x_t, y_t)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=100,
#                   n_jobs=-1, oob_score=True, random_state=42)

# %%
y_pred_dt = bag_dt.predict(x_tt)

# %%
confusion_matrix(y_tt, y_pred_dt)
# Out:
# array([[123,  16],
#        [ 14, 147]], dtype=int64)

# %%
print(bag_dt.score(x_tt, y_tt))
bag_dt.oob_score_
# Out:
# 0.9
# 0.8614285714285714

# %%
bag_lr = BaggingClassifier(
    estimator=LogisticRegression(),
    n_estimators=100,
    max_samples=1.0,
    bootstrap=True,
    oob_score=True,
    random_state=42,
    n_jobs=-1
)
bag_lr.fit(x_t, y_t)
# Out:
# BaggingClassifier(estimator=LogisticRegression(), n_estimators=100, n_jobs=-1,
#                   oob_score=True, random_state=42)

# %%
y_pred_lr = bag_lr.predict(x_tt)

# %%
print(bag_lr.score(x_tt, y_tt))
bag_lr.oob_score_
# Out:
# 0.8
# 0.7657142857142857

# %%
bag_dt = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=10000,
    max_samples=1.0,
    bootstrap=True,
    oob_score=True,
    random_state=42,
    n_jobs=-1,
    max_features=2
)
bag_dt.fit(x_t, y_t)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), max_features=2,
#                   n_estimators=10000, n_jobs=-1, oob_score=True,
#                   random_state=42)

# %%
y_pred_dt = bag_dt.predict(x_tt)

# %%
print(bag_dt.score(x_tt, y_tt))
bag_dt.oob_score_
# Out:
# 0.8433333333333334
# 0.8128571428571428

# %%
confusion_matrix(y_tt, y_pred_dt)
# Out:
# array([[121,  18],
#        [ 29, 132]], dtype=int64)

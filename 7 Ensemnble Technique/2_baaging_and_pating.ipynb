# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier

# %%
x, y = make_moons(n_samples=500, noise=.30, random_state=42)
x_t, x_tt, y_t, y_tt = train_test_split(x, y, random_state=42)

# %%
bag_clf = BaggingClassifier(DecisionTreeClassifier(), n_estimators=500,  max_samples=100, n_jobs=-1, random_state=42)
bag_clf.fit(x_t, y_t)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), max_samples=100,
#                   n_estimators=500, n_jobs=-1, random_state=42)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
dtc = DecisionTreeClassifier(random_state=42)
dtc.fit(x_t, y_t)
y_pred = dtc.predict(x_tt)

# %%
print(f"accuracy : " , accuracy_score(y_tt, y_pred))
print(classification_report(y_tt, y_pred))
print(confusion_matrix(y_tt, y_pred))
# Out:
# accuracy :  0.856
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86        61
#            1       0.93      0.78      0.85        64
#
#     accuracy                           0.86       125
#    macro avg       0.86      0.86      0.86       125
# weighted avg       0.87      0.86      0.86       125
#
# [[57  4]
#  [14 50]]

# %%
bag_clf_pred = bag_clf.predict(x_tt)

# %%
print(f"accuracy : " , accuracy_score(y_tt, bag_clf_pred))
print(classification_report(y_tt, bag_clf_pred))
print(confusion_matrix(y_tt, bag_clf_pred))
# Out:
# accuracy :  0.904
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90        61
#            1       0.93      0.88      0.90        64
#
#     accuracy                           0.90       125
#    macro avg       0.91      0.90      0.90       125
# weighted avg       0.91      0.90      0.90       125
#
# [[57  4]
#  [ 8 56]]

# %%
bag_clf.score(x_t, y_t)
# Out:
# 0.9386666666666666

# %%
bag_clf.score(x_tt, y_tt)
# Out:
# 0.904

# %% [markdown]
# ## out of bag evalution :
# for those whicjh data neverd apperd to any model , beacuz of replacemnet of data ( estaminated 37 %  of total data )

# %% [markdown]
# ### use pramater oob_score = True

# %%
bag_clf2 = BaggingClassifier(DecisionTreeClassifier(), n_estimators=500, oob_score=True, max_samples=100, n_jobs=-1, random_state=42)
bag_clf2.fit(x_t, y_t)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), max_samples=100,
#                   n_estimators=500, n_jobs=-1, oob_score=True, random_state=42)

# %%
bag_clf2.oob_score_
# Out:
# 0.9253333333333333

# %%
bag_clf2.score(x_tt, y_tt)
# Out:
# 0.904

# %%
bag_clf_pred2 = bag_clf2.predict(x_tt)
print(f"accuracy : " , accuracy_score(y_tt, bag_clf_pred2))
print(classification_report(y_tt, bag_clf_pred2))
print(confusion_matrix(y_tt, bag_clf_pred2))
# Out:
# accuracy :  0.904
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90        61
#            1       0.93      0.88      0.90        64
#
#     accuracy                           0.90       125
#    macro avg       0.91      0.90      0.90       125
# weighted avg       0.91      0.90      0.90       125
#
# [[57  4]
#  [ 8 56]]

# %%
bag_clf2.oob_decision_function_
# Out:
# array([[0.35579515, 0.64420485],
#        [0.43513514, 0.56486486],
#        [1.        , 0.        ],
#        [0.01030928, 0.98969072],
#        [0.03174603, 0.96825397],
#        [0.07672634, 0.92327366],
#        [0.39189189, 0.60810811],
#        [0.06145251, 0.93854749],
#        [0.92689295, 0.07310705],
#        [0.88205128, 0.11794872],
#        [0.59850374, 0.40149626],
#        [0.04896907, 0.95103093],
#        [0.7565445 , 0.2434555 ],
#        [0.81377551, 0.18622449],
#        [0.88528678, 0.11471322],
#        [0.07407407, 0.92592593],
#        [0.04738155, 0.95261845],
#        [0.92051282, 0.07948718],
#        [0.69974555, 0.30025445],
#        [0.94358974, 0.05641026],
#        [0.06100796, 0.93899204],
#        [0.224     , 0.776     ],
#        [0.9125964 , 0.0874036 ],
#        [0.98746867, 0.01253133],
#        [0.95967742, 0.04032258],
#        [0.        , 1.        ],
#        [0.94255875, 0.05744125],
#        [1.        , 0.        ],
# ...
